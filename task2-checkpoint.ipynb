# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
Y_train = train["label"]
X_train = train.drop(labels = ["label"],axis = 1)
X_train = X_train / 255.0
X_test = test / 255.0
X_train = X_train.values.reshape(-1,28,28,1)
X_test = X_test.values.reshape(-1,28,28,1)
Y_train = to_categorical(Y_train, num_classes = 10)
import matplotlib.pyplot as plt
plt.figure(figsize=(15,4.5))
for i in range(30):  
    plt.subplot(3, 10, i+1)
    plt.imshow(X_train[i].reshape((28,28)),cmap=plt.cm.binary)
    plt.axis('off')
plt.subplots_adjust(wspace=-0.1, hspace=-0.1)
plt.show()

# %%
train.shape
# Out:
# (42000, 785)

# %%
test.shape
# Out:
# (28000, 784)

# %%
# CREATE MORE IMAGES VIA DATA AUGMENTATION
datagen = ImageDataGenerator(
        rotation_range=10,  
        zoom_range = 0.10,  
        width_shift_range=0.1, 
        height_shift_range=0.1)

# %%
# PREVIEW AUGMENTED IMAGES
X_train3 = X_train[9,].reshape((1, 28, 28, 1))
Y_train3 = Y_train[9,].reshape((1, 10))

plt.figure(figsize=(15, 4.5))
i = 0  # Initialize the counter
for X_batch, Y_batch in datagen.flow(X_train3, Y_train3):
    plt.subplot(3, 10, i + 1)
    plt.imshow(X_batch[0].reshape((28, 28)), cmap=plt.cm.binary)
    plt.axis('off')
    i += 1  # Increment the counter
    if i >= 30:  # Stop after 30 images
        break

plt.subplots_adjust(wspace=-0.1, hspace=-0.1)
plt.show()

# %%
# BUILD CONVOLUTIONAL NEURAL NETWORKS
nets = 3
model = [0] *nets
for j in range(nets):
    model[j] = Sequential()

    model[j].add(Conv2D(32, kernel_size = 3, activation='relu', input_shape = (28, 28, 1)))
    model[j].add(BatchNormalization())
    model[j].add(Conv2D(32, kernel_size = 3, activation='relu'))
    model[j].add(BatchNormalization())
    model[j].add(Conv2D(32, kernel_size = 5, strides=2, padding='same', activation='relu'))
    model[j].add(BatchNormalization())
    model[j].add(Dropout(0.4))

    model[j].add(Conv2D(64, kernel_size = 3, activation='relu'))
    model[j].add(BatchNormalization())
    model[j].add(Conv2D(64, kernel_size = 3, activation='relu'))
    model[j].add(BatchNormalization())
    model[j].add(Conv2D(64, kernel_size = 5, strides=2, padding='same', activation='relu'))
    model[j].add(BatchNormalization())
    model[j].add(Dropout(0.4))
    
    model[j].add(Conv2D(128, kernel_size = 4, activation='relu'))
    model[j].add(BatchNormalization())
    model[j].add(Flatten())
    model[j].add(Dropout(0.4))
    model[j].add(Dense(10, activation='softmax'))

    # COMPILE WITH ADAM OPTIMIZER AND CROSS ENTROPY COST
    model[j].compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.model_selection import train_test_split
import numpy as np

# Learning Rate Scheduler
def lr_schedule(epoch):
    lr = 0.001
    if epoch > 5:
        lr *= 0.2
    return lr

annealer = LearningRateScheduler(lr_schedule)

# Ensure `nets` is defined
nets = 3  # Change this to however many networks you want

history = []  
epochs = 25

for j in range(nets):
    # ✅ Define a new model inside the loop
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Split dataset
    X_train2, X_val2, Y_train2, Y_val2 = train_test_split(X_train, Y_train, test_size=0.1)

    # ✅ Train the model
    hist = model.fit(  
        datagen.flow(X_train2, Y_train2, batch_size=64), 
        epochs=epochs,
        steps_per_epoch=X_train2.shape[0] // 64, 
        validation_data=(X_val2, Y_val2),
        callbacks=[annealer], 
        verbose=1  
    )

    history.append(hist)  # ✅ Append history properly

# Print summary after training all networks
for j in range(nets):
    print(f"CNN {j+1}: Max Train Acc={max(history[j].history['accuracy']):.5f}, "
          f"Max Val Acc={max(history[j].history['val_accuracy']):.5f}")
# Out:
# C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/25
# C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6754 - loss: 0.9738 - val_accuracy: 0.9724 - val_loss: 0.0860 - learning_rate: 0.0010
# Epoch 2/25
#   1/590 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9062 - loss: 0.2611
# C:\ProgramData\anaconda3\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.9062 - loss: 0.2611 - val_accuracy: 0.9721 - val_loss: 0.0853 - learning_rate: 0.0010
# Epoch 3/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.9215 - loss: 0.2545 - val_accuracy: 0.9810 - val_loss: 0.0585 - learning_rate: 0.0010
# Epoch 4/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 0.9531 - loss: 0.1616 - val_accuracy: 0.9807 - val_loss: 0.0590 - learning_rate: 0.0010
# Epoch 5/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.9404 - loss: 0.1903 - val_accuracy: 0.9843 - val_loss: 0.0484 - learning_rate: 0.0010
# Epoch 6/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.9844 - loss: 0.0792 - val_accuracy: 0.9845 - val_loss: 0.0475 - learning_rate: 0.0010
# Epoch 7/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9592 - loss: 0.1380 - val_accuracy: 0.9871 - val_loss: 0.0337 - learning_rate: 2.0000e-04
# Epoch 8/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.9844 - loss: 0.0605 - val_accuracy: 0.9869 - val_loss: 0.0337 - learning_rate: 2.0000e-04
# Epoch 9/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - accuracy: 0.9619 - loss: 0.1262 - val_accuracy: 0.9881 - val_loss: 0.0321 - learning_rate: 2.0000e-04
# Epoch 10/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.9688 - loss: 0.1509 - val_accuracy: 0.9881 - val_loss: 0.0323 - learning_rate: 2.0000e-04
# Epoch 11/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9655 - loss: 0.1163 - val_accuracy: 0.9883 - val_loss: 0.0331 - learning_rate: 2.0000e-04
# Epoch 12/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.9844 - loss: 0.0751 - val_accuracy: 0.9879 - val_loss: 0.0329 - learning_rate: 2.0000e-04
# Epoch 13/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.9692 - loss: 0.1098 - val_accuracy: 0.9893 - val_loss: 0.0307 - learning_rate: 2.0000e-04
# Epoch 14/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - accuracy: 0.9688 - loss: 0.0757 - val_accuracy: 0.9893 - val_loss: 0.0305 - learning_rate: 2.0000e-04
# Epoch 15/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9703 - loss: 0.1044 - val_accuracy: 0.9886 - val_loss: 0.0286 - learning_rate: 2.0000e-04
# Epoch 16/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - accuracy: 0.9531 - loss: 0.1728 - val_accuracy: 0.9888 - val_loss: 0.0285 - learning_rate: 2.0000e-04
# Epoch 17/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9700 - loss: 0.1014 - val_accuracy: 0.9898 - val_loss: 0.0278 - learning_rate: 2.0000e-04
# Epoch 18/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.9898 - val_loss: 0.0278 - learning_rate: 2.0000e-04
# Epoch 19/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.9726 - loss: 0.0936 - val_accuracy: 0.9893 - val_loss: 0.0277 - learning_rate: 2.0000e-04
# Epoch 20/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 1.0000 - loss: 0.0261 - val_accuracy: 0.9893 - val_loss: 0.0280 - learning_rate: 2.0000e-04
# Epoch 21/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.9725 - loss: 0.0938 - val_accuracy: 0.9907 - val_loss: 0.0255 - learning_rate: 2.0000e-04
# Epoch 22/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.9844 - loss: 0.0536 - val_accuracy: 0.9910 - val_loss: 0.0257 - learning_rate: 2.0000e-04
# Epoch 23/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9708 - loss: 0.0959 - val_accuracy: 0.9907 - val_loss: 0.0247 - learning_rate: 2.0000e-04
# Epoch 24/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.9844 - loss: 0.0469 - val_accuracy: 0.9907 - val_loss: 0.0247 - learning_rate: 2.0000e-04
# Epoch 25/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9759 - loss: 0.0851 - val_accuracy: 0.9910 - val_loss: 0.0269 - learning_rate: 2.0000e-04
# Epoch 1/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.6796 - loss: 0.9619 - val_accuracy: 0.9717 - val_loss: 0.0937 - learning_rate: 0.0010
# Epoch 2/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.9375 - loss: 0.1940 - val_accuracy: 0.9717 - val_loss: 0.0956 - learning_rate: 0.0010
# Epoch 3/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9221 - loss: 0.2541 - val_accuracy: 0.9814 - val_loss: 0.0577 - learning_rate: 0.0010
# Epoch 4/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.9219 - loss: 0.1954 - val_accuracy: 0.9812 - val_loss: 0.0580 - learning_rate: 0.0010
# Epoch 5/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9460 - loss: 0.1774 - val_accuracy: 0.9860 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 6/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.9688 - loss: 0.0576 - val_accuracy: 0.9857 - val_loss: 0.0466 - learning_rate: 0.0010
# Epoch 7/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9612 - loss: 0.1341 - val_accuracy: 0.9864 - val_loss: 0.0438 - learning_rate: 2.0000e-04
# Epoch 8/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.9688 - loss: 0.0613 - val_accuracy: 0.9864 - val_loss: 0.0439 - learning_rate: 2.0000e-04
# Epoch 9/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9653 - loss: 0.1194 - val_accuracy: 0.9881 - val_loss: 0.0386 - learning_rate: 2.0000e-04
# Epoch 10/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.9844 - loss: 0.1015 - val_accuracy: 0.9879 - val_loss: 0.0384 - learning_rate: 2.0000e-04
# Epoch 11/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9654 - loss: 0.1137 - val_accuracy: 0.9874 - val_loss: 0.0375 - learning_rate: 2.0000e-04
# Epoch 12/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.9844 - loss: 0.0418 - val_accuracy: 0.9874 - val_loss: 0.0374 - learning_rate: 2.0000e-04
# Epoch 13/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9692 - loss: 0.1074 - val_accuracy: 0.9888 - val_loss: 0.0339 - learning_rate: 2.0000e-04
# Epoch 14/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.9062 - loss: 0.2871 - val_accuracy: 0.9888 - val_loss: 0.0340 - learning_rate: 2.0000e-04
# Epoch 15/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9711 - loss: 0.1038 - val_accuracy: 0.9886 - val_loss: 0.0343 - learning_rate: 2.0000e-04
# Epoch 16/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 0.9844 - loss: 0.0558 - val_accuracy: 0.9886 - val_loss: 0.0344 - learning_rate: 2.0000e-04
# Epoch 17/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9700 - loss: 0.0989 - val_accuracy: 0.9893 - val_loss: 0.0336 - learning_rate: 2.0000e-04
# Epoch 18/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 1.0000 - loss: 0.0335 - val_accuracy: 0.9893 - val_loss: 0.0336 - learning_rate: 2.0000e-04
# Epoch 19/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9727 - loss: 0.0940 - val_accuracy: 0.9890 - val_loss: 0.0331 - learning_rate: 2.0000e-04
# Epoch 20/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.9844 - loss: 0.0971 - val_accuracy: 0.9890 - val_loss: 0.0331 - learning_rate: 2.0000e-04
# Epoch 21/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.9735 - loss: 0.0897 - val_accuracy: 0.9900 - val_loss: 0.0321 - learning_rate: 2.0000e-04
# Epoch 22/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.9844 - loss: 0.0729 - val_accuracy: 0.9900 - val_loss: 0.0322 - learning_rate: 2.0000e-04
# Epoch 23/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.9749 - loss: 0.0831 - val_accuracy: 0.9905 - val_loss: 0.0316 - learning_rate: 2.0000e-04
# Epoch 24/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 1.0000 - loss: 0.0316 - val_accuracy: 0.9907 - val_loss: 0.0317 - learning_rate: 2.0000e-04
# Epoch 25/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9739 - loss: 0.0956 - val_accuracy: 0.9902 - val_loss: 0.0312 - learning_rate: 2.0000e-04
# Epoch 1/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.6675 - loss: 0.9969 - val_accuracy: 0.9717 - val_loss: 0.0915 - learning_rate: 0.0010
# Epoch 2/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.8906 - loss: 0.4137 - val_accuracy: 0.9702 - val_loss: 0.0937 - learning_rate: 0.0010
# Epoch 3/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9208 - loss: 0.2598 - val_accuracy: 0.9817 - val_loss: 0.0612 - learning_rate: 0.0010
# Epoch 4/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - accuracy: 0.9844 - loss: 0.1196 - val_accuracy: 0.9814 - val_loss: 0.0608 - learning_rate: 0.0010
# Epoch 5/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9416 - loss: 0.1927 - val_accuracy: 0.9821 - val_loss: 0.0576 - learning_rate: 0.0010
# Epoch 6/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.9531 - loss: 0.1189 - val_accuracy: 0.9821 - val_loss: 0.0560 - learning_rate: 0.0010
# Epoch 7/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9588 - loss: 0.1408 - val_accuracy: 0.9857 - val_loss: 0.0469 - learning_rate: 2.0000e-04
# Epoch 8/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.9375 - loss: 0.1989 - val_accuracy: 0.9857 - val_loss: 0.0470 - learning_rate: 2.0000e-04
# Epoch 9/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9624 - loss: 0.1289 - val_accuracy: 0.9848 - val_loss: 0.0466 - learning_rate: 2.0000e-04
# Epoch 10/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - accuracy: 0.9688 - loss: 0.1306 - val_accuracy: 0.9848 - val_loss: 0.0465 - learning_rate: 2.0000e-04
# Epoch 11/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9651 - loss: 0.1228 - val_accuracy: 0.9845 - val_loss: 0.0483 - learning_rate: 2.0000e-04
# Epoch 12/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.9844 - loss: 0.3565 - val_accuracy: 0.9852 - val_loss: 0.0477 - learning_rate: 2.0000e-04
# Epoch 13/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9675 - loss: 0.1093 - val_accuracy: 0.9857 - val_loss: 0.0437 - learning_rate: 2.0000e-04
# Epoch 14/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - accuracy: 0.9844 - loss: 0.1215 - val_accuracy: 0.9860 - val_loss: 0.0438 - learning_rate: 2.0000e-04
# Epoch 15/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.9700 - loss: 0.1084 - val_accuracy: 0.9867 - val_loss: 0.0433 - learning_rate: 2.0000e-04
# Epoch 16/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.9688 - loss: 0.1600 - val_accuracy: 0.9862 - val_loss: 0.0436 - learning_rate: 2.0000e-04
# Epoch 17/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9692 - loss: 0.1028 - val_accuracy: 0.9879 - val_loss: 0.0411 - learning_rate: 2.0000e-04
# Epoch 18/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.9531 - loss: 0.1398 - val_accuracy: 0.9881 - val_loss: 0.0410 - learning_rate: 2.0000e-04
# Epoch 19/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9698 - loss: 0.1013 - val_accuracy: 0.9874 - val_loss: 0.0380 - learning_rate: 2.0000e-04
# Epoch 20/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.9531 - loss: 0.0965 - val_accuracy: 0.9876 - val_loss: 0.0379 - learning_rate: 2.0000e-04
# Epoch 21/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9728 - loss: 0.0938 - val_accuracy: 0.9881 - val_loss: 0.0393 - learning_rate: 2.0000e-04
# Epoch 22/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.9844 - loss: 0.0624 - val_accuracy: 0.9881 - val_loss: 0.0396 - learning_rate: 2.0000e-04
# Epoch 23/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9738 - loss: 0.0895 - val_accuracy: 0.9876 - val_loss: 0.0429 - learning_rate: 2.0000e-04
# Epoch 24/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.9688 - loss: 0.0787 - val_accuracy: 0.9874 - val_loss: 0.0432 - learning_rate: 2.0000e-04
# Epoch 25/25
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9735 - loss: 0.0901 - val_accuracy: 0.9888 - val_loss: 0.0368 - learning_rate: 2.0000e-04
# CNN 1: Max Train Acc=1.00000, Max Val Acc=0.99095
# CNN 2: Max Train Acc=1.00000, Max Val Acc=0.99071
# CNN 3: Max Train Acc=0.98438, Max Val Acc=0.98881

# %%
results = np.zeros( (X_test.shape[0],10) ) 
for j in range(nets):
    results = results + model.predict(X_test)
results = np.argmax(results,axis = 1)
results = pd.Series(results,name="Label")
submission = pd.concat([pd.Series(range(1,28001),name = "ImageId"),results],axis = 1)
submission.to_csv("MNIST-CNN-ENSEMBLE.csv",index=False)
# Out:
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
# PREVIEW PREDICTIONS
plt.figure(figsize=(15,6))
for i in range(40):  
    plt.subplot(4, 10, i+1)
    plt.imshow(X_test[i].reshape((28,28)),cmap=plt.cm.binary)
    plt.title("predict=%d" % results[i],y=0.9)
    plt.axis('off')
plt.subplots_adjust(wspace=0.3, hspace=-0.1)
plt.show()
